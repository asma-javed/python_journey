# %%
# arthmetic operators
a=8
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**2)
print(a%b)
print(a//b)
# Out:
# 13
# 3
# 40
# 1.6
# 64
# 3
# 1
# 5
# 8
# 16
# False
# True
# True
# False
# True
# False
# False
# False
# True

# %%
#assignment operators
x=5
print(x)
x+=3
print(x)
x*=2
print(x)
# Out:
# 5
# 8
# 16

# %%
#comparison operators
a=5
b=10
print(a==b)
print(a!=b)
print(a<b)
print(a>b)
print(a<=b)
print(a>=b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
#logical operators
a=10
b=15
print (a>10 and b<20)
print (a<10 and b<20)
print (not(a>b))
# Out:
# False
# False
# True

# %%
#list
fruit=["apple","mango","banana"]
print(fruit)
print(fruit[2])
fruit.append("orange")
print(fruit)

#practice
numbers=[2,4,6,8,0]
print ("Sum of all numbers: ",sum(numbers))
numbers[2]=5
print(numbers)
# Out:
# ['apple', 'mango', 'banana']
# banana
# ['apple', 'mango', 'banana', 'orange']
# Sum of all numbers:  20
# [2, 4, 5, 8, 0]

# %%
#tuple
colours=["red","yellow","green"]
print(colours)

#practice tuples
cities=["lahore","pindi","BWN","Bahawalpur","Karachi"]
print(cities[0],cities[4])
# Out:
# ['red', 'yellow', 'green']
# lahore Karachi

# %%
#dictionary
student={
    "name":"Asma Javed",
    "age":20,
    "is_student":True
}
print(student["name"])
student["age"]=21
print(student)

#practice
book={
    "title":"The Great Gatsby",
    "author":"F. Scott Fitzgerald",
    "year":1925
}
print(book)
book["title"]="To Kill a Mockingbird"
print(book)
# Out:
# Asma Javed
# {'name': 'Asma Javed', 'age': 21, 'is_student': True}
# {'title': 'The Great Gatsby', 'author': 'F. Scott Fitzgerald', 'year': 1925}
# {'title': 'To Kill a Mockingbird', 'author': 'F. Scott Fitzgerald', 'year': 1925}

# %%
#functions
def add(a,b):
    return a+b
result=add(5,3)
print(result)

#practice
def add(x,y):
    return x+y
resutl=add(9,9)
print(result)

num=int(input("Enter your number:"))
def num_check(num):
    if num%2==0:
        print("Even")
    else:
        print("Odd")
num_check(num)
# Out:
# 8
# 8
# Enter your number: 79
# Odd

# %%
#Mini project
student={
    "name":"Asma",
    "age" :20,
    "grades":[50,90,95,80]
}
def cal_grades(grades):
    return sum(grades)/len(grades)
print(f"{student["name"]} has an average grade of {cal_grades(student["grades"])}")
# Out:
# Asma has an average grade of 78.75
